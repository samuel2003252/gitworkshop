# %%
num = int(input("Enter the value of n: "))
i=1
sum = 0
while i<=num:
    sum = sum + i
    i = i+1
print("Sum is:", sum)
# Out:
# Enter the value of n: 5
# Sum is: 15

# %%
i = 100
sum = 0
while i<= 200:
  if i % 5 == 0 and i % 7 == 0:
    print(i)
    sum = sum + i
  i = i+1
print("Sum is:", sum)
# Out:
# 105
# 140
# 175
# Sum is: 420

# %%
i = 1000
sum = 0
while i<= 1500:
  if i % 15 == 0 and i % 12 == 0:
    print(i)
    sum = sum + i
  i = i+1
print("Sum is:", sum)
# Out:
# 1020
# 1080
# 1140
# 1200
# 1260
# 1320
# 1380
# 1440
# 1500
# Sum is: 11340

# %%
num = int(input("Enter the value of n: "))
i = 1
fact = 1
while i<=num:
  fact = fact * i
  i = i+1
print("Factorial is:",fact)
# Out:
# Enter the value of n: 5
# Factorial is: 120

# %%
n1 = 0
n2 = 1
i = 0
no = int(input("Enter the value of n: "))
if no <= 0:
   print("Unable to find fibonacci series")
elif no == 1:
   print(n1)
else:
   while i < no:
     print(n1)
     final = n1 + n2
     n1 = n2
     n2 = final
     i = i + 1
# Out:
# Enter the value of n: 5
# 0
# 1
# 1
# 2
# 3
